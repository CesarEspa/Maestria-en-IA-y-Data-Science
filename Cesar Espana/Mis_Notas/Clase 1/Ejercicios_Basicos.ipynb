# %% [markdown]
# # Clase 1: Ejercicios Prácticos de Python
#
# Este notebook contiene ejercicios simples para practicar los conceptos básicos de Python vistos en la clase 1 de Introducción a IA y Ciencia de Datos. Resuelve cada ejercicio en la celda correspondiente y prueba tus conocimientos.

# %% [markdown]
# ## Ejercicio 1: Variables y tipos
#
# Crea una variable llamada `nombre` que almacene tu nombre y una variable `edad` que almacene tu edad. Muestra ambos valores usando `print()`.

# %%
# Escribe tu solución aquí
nombre = "cesar"
edad = 24

print (f"Hola, mi nombre es  {nombre}  y tengo  {edad}  años.")
# Out:
# Hola, mi nombre es  cesar  y tengo  24  años.

# %% [markdown]
# ## Ejercicio 2: Operaciones aritméticas
#
# Declara dos variables numéricas, súmalas, réstalas, multiplícalas y divídelas. Muestra los resultados con `print()`.

# %%
# Escribe tu solución aquí
num1 = 5
num2 = 10

suma = num1 + num2;
resta = num2 - num1;
producto = num1 * num2;
cociente = num2 / num1;

print(f"Suma: {suma}, Resta: {resta}, Producto: {producto}, Cociente: {cociente}")
# Out:
# Suma: 15, Resta: 5, Producto: 50, Cociente: 2.0

# %% [markdown]
# ## Ejercicio 3: Listas
#
# Crea una lista con 5 elementos (pueden ser números o palabras). Muestra la lista y accede al primer y último elemento usando índices.

# %%
# Escribe tu solución aquí

# Crea una lista con 5 elementos (pueden ser números o palabras). Muestra la lista y accede al primer y último elemento usando índices.

mi_lista = [10, 20, 30, 40, "Cesar"]

print(f"Lista completa: {mi_lista}")
print(f"Primer elemento: {mi_lista[0]}")
print(f"Último elemento: {mi_lista[-1]}")
# Out:
# Lista completa: [10, 20, 30, 40, 'Cesar']
# Primer elemento: 10
# Último elemento: Cesar

# %% [markdown]
# ## Ejercicio 4: Diccionarios
#
# Crea un diccionario que almacene información de una persona (por ejemplo: nombre, edad, ciudad). Muestra el diccionario y accede al valor de la clave `nombre`.

# %%
# Escribe tu solución aquí
#Crea un diccionario que almacene información de una persona (por ejemplo: nombre, edad, ciudad). Muestra el diccionario y accede al valor de la clave `nombre`.

persona = {"nombre": "Cesar", "edad": 24, "ciudad": "Madrid"}
print(f"Diccionario completo: {persona}")
print(f"Nombre: {persona['nombre']}")
# Out:
# Diccionario completo: {'nombre': 'Cesar', 'edad': 24, 'ciudad': 'Madrid'}
# Nombre: Cesar

# %% [markdown]
# ## Ejercicio 5: Conversión de tipos
#
# Convierte una variable de tipo entero a cadena y una cadena a entero. Muestra los resultados y verifica los tipos con la función `type()`.

# %%
# Escribe tu solución aquí

numero = 7

cadena = str(numero)
print(type(cadena))  # Debería mostrar <class 'str'>

numero1 = int(cadena)
print(type(numero1))  # Debería mostrar <class 'int'>
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ## Ejercicio 6: Tu propio ejemplo
#
# Crea un ejercicio simple usando lo que has aprendido (variables, operaciones, listas o diccionarios). Escribe el enunciado y la solución en las celdas siguientes.

# %%
estudiantes = {
    "estudiante1": {
        "nombre": "Ana",
        "edad": 20,
        "calificaciones": [85, 90, 88]
    },
    "estudiante2": {
        "nombre": "Carlos",
        "edad": 22,
        "calificaciones": [78, 82, 80]
    },
    "estudiante3": {
        "nombre": "María",
        "edad": 21,
        "calificaciones": [92, 95, 89]
    },
    "estudiante4": {
        "nombre": "Cesar",
        "edad": 25,
        "calificaciones": [99, 95, 89]
    }
}

# Calcular y mostrar el promedio para cada estudiante
for clave, info in estudiantes.items():
    nombre = info["nombre"]
    calificaciones = info["calificaciones"]
    promedio = sum(calificaciones) / len(calificaciones)  # Operación para calcular promedio
    print(f"{nombre}: {promedio:.2f}")
# Out:
# Ana: 87.67
# Carlos: 80.00
# María: 92.00
# Cesar: 94.33
